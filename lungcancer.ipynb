# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('updated_survey_lung_cancer.csv')
data.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         1         2                  2         2
# 1                2         2         1                  1         1
# 2                1         1         2                  1         2
# 3                1         1         1                  2         1
# 4                1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# 0                    2                      2           2            1
# ...

# %%
data.describe().T
# Out:
#                        count       mean       std   min   25%   50%   75%  \
# AGE                    309.0  62.673139  8.210301  21.0  57.0  62.0  69.0
# SMOKING                309.0   1.563107  0.496806   1.0   1.0   2.0   2.0
# YELLOW_FINGERS         309.0   1.569579  0.495938   1.0   1.0   2.0   2.0
# ANXIETY                309.0   1.498382  0.500808   1.0   1.0   1.0   2.0
# PEER_PRESSURE          309.0   1.501618  0.500808   1.0   1.0   2.0   2.0
# CHRONIC DISEASE        309.0   1.504854  0.500787   1.0   1.0   2.0   2.0
# ALLERGY                309.0   1.556634  0.497588   1.0   1.0   2.0   2.0
# WHEEZING               309.0   1.556634  0.497588   1.0   1.0   2.0   2.0
# ALCOHOL CONSUMING      309.0   1.556634  0.497588   1.0   1.0   2.0   2.0
# COUGHING               309.0   1.579288  0.494474   1.0   1.0   2.0   2.0
# SHORTNESS OF BREATH    309.0   1.640777  0.480551   1.0   1.0   2.0   2.0
# SWALLOWING DIFFICULTY  309.0   1.469256  0.499863   1.0   1.0   1.0   2.0
# ...

# %%
n_data = data.dropna()

# %%
n_data['LUNG_CANCER'].value_counts()
# Out:
# LUNG_CANCER
# 1    270
# 2     39
# Name: count, dtype: int64

# %%
groups = n_data[['GENDER', 'LUNG_CANCER']]
grouped_data = groups.groupby('GENDER')['LUNG_CANCER'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(8, 5), dpi=80)
sns.barplot(x=grouped_data.index, y=grouped_data.values, order=grouped_data.index)
ax.set_title("GENDER Vs LUNG_CANCER", size=20)
ax.set_xlabel('GENDER', size=20)
ax.set_ylabel('AVG No. of LUNG_CANCER', size=20)
# Out:
# Text(0, 0.5, 'AVG No. of LUNG_CANCER')

# %%
groups = n_data [['SMOKING', 'LUNG_CANCER']]
grouped_data = groups.groupby('SMOKING')['LUNG_CANCER'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(8, 5), dpi = 80)
sns.barplot(x=grouped_data.index, y = grouped_data.values, hue= grouped_data, order=grouped_data.index)
ax.set_title("SMOKING Vs LUNG_CANCER", size = 20)
ax.set_xlabel('SMOKING', size = 20)
ax.set_ylabel('AVG No. of LUNG_CANCER', size = 20)
# Out:
# Text(0, 0.5, 'AVG No. of LUNG_CANCER')

# %%
groups = n_data [['CHRONIC DISEASE', 'LUNG_CANCER']]
grouped_data = groups.groupby('CHRONIC DISEASE')['LUNG_CANCER'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(8, 5), dpi = 80)
sns.barplot(x=grouped_data.index, y = grouped_data.values, hue= grouped_data, order=grouped_data.index)
ax.set_title("CHRONIC DISEASE Vs LUNG_CANCER", size = 20)
ax.set_xlabel('CHRONIC DISEASE', size = 20)
ax.set_ylabel('AVG No. of LUNG_CANCER', size = 20)
# Out:
# Text(0, 0.5, 'AVG No. of LUNG_CANCER')

# %%
groups = n_data [['YELLOW_FINGERS', 'LUNG_CANCER']]
grouped_data = groups.groupby('YELLOW_FINGERS')['LUNG_CANCER'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(8, 5), dpi = 80)
sns.barplot(x=grouped_data.index, y = grouped_data.values, hue= grouped_data, order=grouped_data.index)
ax.set_title("YELLOW_FINGERS Vs LUNG_CANCER", size = 20)
ax.set_xlabel('YELLOW_FINGERS', size = 20)
ax.set_ylabel('AVG No. of LUNG_CANCER', size = 20)
# Out:
# Text(0, 0.5, 'AVG No. of LUNG_CANCER')

# %%
groups = n_data [['WHEEZING', 'LUNG_CANCER']]
grouped_data = groups.groupby('WHEEZING')['LUNG_CANCER'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(8, 5), dpi = 80)
sns.barplot(x=grouped_data.index, y = grouped_data.values, hue= grouped_data, order=grouped_data.index)
ax.set_title("WHEEZING Vs LUNG_CANCER", size = 20)
ax.set_xlabel('WHEEZING', size = 20)
ax.set_ylabel('AVG No. of LUNG_CANCER', size = 20)
# Out:
# Text(0, 0.5, 'AVG No. of LUNG_CANCER')

# %%
groups = n_data [['ALCOHOL CONSUMING', 'LUNG_CANCER']]
grouped_data = groups.groupby('ALCOHOL CONSUMING')['LUNG_CANCER'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(8, 5), dpi = 80)
sns.barplot(x=grouped_data.index, y = grouped_data.values, hue= grouped_data, order=grouped_data.index)
ax.set_title("ALCOHOL CONSUMING Vs LUNG_CANCER", size = 20)
ax.set_xlabel('ALCOHOL CONSUMING', size = 20)
ax.set_ylabel('AVG No. of LUNG_CANCER', size = 20)
# Out:
# Text(0, 0.5, 'AVG No. of LUNG_CANCER')

# %%
groups = n_data [['COUGHING', 'LUNG_CANCER']]
grouped_data = groups.groupby('COUGHING')['LUNG_CANCER'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(8, 5), dpi = 80)
sns.barplot(x=grouped_data.index, y = grouped_data.values, hue= grouped_data, order=grouped_data.index)
ax.set_title("COUGHING Vs LUNG_CANCER", size = 20)
ax.set_xlabel('COUGHING', size = 20)
ax.set_ylabel('AVG No. of LUNG_CANCER', size = 20)
# Out:
# Text(0, 0.5, 'AVG No. of LUNG_CANCER')

# %%
groups = n_data [['SHORTNESS OF BREATH', 'LUNG_CANCER']]
grouped_data = groups.groupby('SHORTNESS OF BREATH')['LUNG_CANCER'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(8, 5), dpi = 80)
sns.barplot(x=grouped_data.index, y = grouped_data.values, hue= grouped_data, order=grouped_data.index)
ax.set_title("SHORTNESS OF BREATH Vs LUNG_CANCER", size = 20)
ax.set_xlabel('SHORTNESS OF BREATH', size = 20)
ax.set_ylabel('AVG No. of LUNG_CANCER', size = 20)
# Out:
# Text(0, 0.5, 'AVG No. of LUNG_CANCER')

# %%
groups = n_data [['CHEST PAIN', 'LUNG_CANCER']]
grouped_data = groups.groupby('CHEST PAIN')['LUNG_CANCER'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(8, 5), dpi = 80)
sns.barplot(x=grouped_data.index, y = grouped_data.values, hue= grouped_data, order=grouped_data.index)
ax.set_title("CHEST PAIN Vs LUNG_CANCER", size = 20)
ax.set_xlabel('CHEST PAIN', size = 20)
ax.set_ylabel('AVG No. of LUNG_CANCER', size = 20)
# Out:
# Text(0, 0.5, 'AVG No. of LUNG_CANCER')

# %%
x = n_data.drop(columns=['LUNG_CANCER'])
y= n_data['LUNG_CANCER']

# %%
from category_encoders import BinaryEncoder
categorycal_features = ['GENDER']
encoder = BinaryEncoder()
x_encoded = encoder.fit_transform(x[categorycal_features])
x = x.drop(categorycal_features, axis=1)
x = x.reset_index(drop=True)
x_encoded = x_encoded.reset_index(drop=True)
x = pd.concat([x, x_encoded], axis=1)

# %%
y.value_counts()
# Out:
# LUNG_CANCER
# 1    270
# 2     39
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x, y = smote.fit_resample(x, y)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.25, random_state=43)

# %%
y.value_counts()
# Out:
# LUNG_CANCER
# 1    270
# 2    270
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score, precision_score

# %%
from sklearn.tree import DecisionTreeClassifier

dcs = DecisionTreeClassifier()
dcs.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from joblib import dump, load
import graphviz
dcs = DecisionTreeClassifier()
dcs.fit(x_train, y_train)

export_graphviz(dcs, out_file='tree.dot', filled=True, feature_names=x_train.columns)

with open('tree.dot') as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

#dump(dcs, "decision_tree_model.joblib")

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score
)
prediction = dcs.predict(x_test)

accuracy = accuracy_score(prediction, y_test)
precision = precision_score(prediction, y_test)

print(f"Accuracy: {accuracy*100}")
print(f"Precision: {precision*100}")
# Out:
# Accuracy: 94.81481481481482
# Precision: 96.875

# %%
loaded_model = load("decision_tree_model.joblib")
expected_features = loaded_model.feature_names_in_
x_test = x_test.reindex(columns=expected_features, fill_value=0)
prediction = loaded_model.predict(x_test)
